# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline  

from yolo import YOLO
from numba import cuda
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.5/dist-packages/numba/errors.py:131: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
img = cv2.imread('/home/dh/Pictures/frisbee.jpg')
img2 = cv2.imread('/home/dh/Pictures/dog_two.jpg')
img2 = cv2.resize(img2, (img.shape[1], img.shape[0]))
img3 = cv2.imread('/home/dh/Pictures/puppy-dog.jpg')
img3 = cv2.resize(img3, (img.shape[1], img.shape[0]))

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
batch_size = 1
yolo = YOLO(bgr=True, batch_size=batch_size)
# Out:
# /home/dh/Workspace/keras-yolo3/model_data/yolov3.h5 model, anchors, and classes loaded.
# Inference batch size: 1
# Warming up...
# YOLO warmed up!

# %%
yolo.close_session()
del yolo
cuda.select_device(0)
cuda.close()

# %% [markdown]
# # ABALATION STUDY

# %% [markdown]
# ## Effect of Batching on Inference Time

# %% [markdown]
# ## Effect of Batching on Accuracy
